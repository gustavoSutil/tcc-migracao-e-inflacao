# %%
import pandas as pd
import plotly.express as px
from src.pre_process.preprocess_aluguel_fipezap import  preprocessar_fipezap_anual

cidade_ibge = {
    "São Paulo": "3550308",
    "Barueri": "3505708",
    "Campinas": "3509502",
    "Diadema": "3513801",
    "Guarujá": "3518702",
    "Guarulhos": "3518801",
    "Osasco": "3534401",
    "Praia Grande": "3541007",
    "Ribeirão Preto": "3543409",
    "Santo André": "3547809",
    "Santos": "3548500",
    "São Bernardo do Campo": "3548708",
    "São Caetano do Sul": "3548807",
    "São José do Rio Preto": "3549805",
    "São José dos Campos": "3549904",
    "São Vicente": "3551009",
    "Rio de Janeiro": "3304557",
    "Niterói": "3303302",
    "Belo Horizonte": "3106200",
    "Betim": "3106705",
    "Contagem": "3118601",
    "Porto Alegre": "4314902",
    "Canoas": "4304606",
    "Caxias do Sul": "4305108",
    "Novo Hamburgo": "4313400",
    "Pelotas": "4314408",
    "Santa Maria": "4316908",
    "São Leopoldo": "4318706",
    "Curitiba": "4106902",
    "Londrina": "4113700",
    "São José dos Pinhais": "4125506",
    "Florianópolis": "4205407",
    "Balneário Camboriú": "4202008",
    "Blumenau": "4202404",
    "Itajaí": "4208203",
    "Itapema": "4208302",
    "Joinville": "4209102",
    "São José": "4216602",   # São José (SC)
    "Vitória": "3205309",
    "Vila Velha": "3205200",
    "Brasília": "5300108",
    "Goiânia": "5208707",
    "Campo Grande": "5002704",
    "Cuiabá": "5103403",
    "Aracaju": "2800308",
    "Fortaleza": "2304400",
    "João Pessoa": "2507507",
    "Maceió": "2704302",
    "Natal": "2408102",
    "Recife": "2611606",
    "Salvador": "2927408",
    "São Luís": "2111300",
    "Teresina": "2211001",
    "Jaboatão dos Guararapes": "2607901",
    "Belém": "1501402",
    "Manaus": "1302603"
}

# %%
preprocessar_fipezap_anual('../data/raw/aluguel_por_cidade_fipezap.xlsx', '../data/processed/aluguel_fipezap.csv', cidade_ibge)
# Out:
# /home/gustavo/Área de Trabalho/tcc-migracao-e-inflacao/src/pre_process/preprocess_aluguel_fipezap.py:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(".", np.nan)
# /home/gustavo/Área de Trabalho/tcc-migracao-e-inflacao/src/pre_process/preprocess_aluguel_fipezap.py:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(".", np.nan)
# ...

# %% [markdown]
# Com o agrupamento muitas cidades perderam dados, isso faz com que o dataset seja diminuido.
#
# (Aracaju, false)	3
# (Barueri, false)	7
# (Belo Horizonte, false)	10
# (Belém, false)	3
# (Brasília, false)	11
# (Campinas, false)	11
# (Campo Grande, false)	3
# (Cuiabá, false)	3
# (Curitiba, false)	11
# (Florianópolis, false)	9
# (Fortaleza, false)	9
# (Goiânia, false)	9
# (Guarulhos, false)	7
# (Joinville, false)	7
# (João Pessoa, false)	3
# (Maceió, false)	3
# (Manaus, false)	3
# (Natal, false)	3
# (Niterói, false)	9
# (Pelotas, false)	7
# (Porto Alegre, false)	11
# (Praia Grande, false)	7
# (Recife, false)	10
# (Ribeirão Preto, false)	7
# (Rio de Janeiro, false)	17
# (Salvador, false)	11
# (Santo André, false)	7
# (Santos, false)	11
# (São Bernardo do Campo, false)	11
# (São José, false)	7
# (São José do Rio Preto, false)	7
# (São José dos Campos, false)	7
# (São Luís, false)	3
# (São Paulo, false)	17
# (Teresina, false)	3
# (Vitória, false)	3
#
# Com isso faz com que  não tenha muita representação do norte e nordeste:
#
#
#
# | Cidade                | Estado | Região       | Nº de anos |
# | --------------------- | ------ | ------------ | ---------- |
# | Aracaju               | SE     | Nordeste     | 3          |
# | Barueri               | SP     | Sudeste      | 7          |
# | Belo Horizonte        | MG     | Sudeste      | 10         |
# | Belém                 | PA     | Norte        | 3          |
# | Brasília              | DF     | Centro-Oeste | 11         |
# | Campinas              | SP     | Sudeste      | 11         |
# | Campo Grande          | MS     | Centro-Oeste | 3          |
# | Cuiabá                | MT     | Centro-Oeste | 3          |
# | Curitiba              | PR     | Sul          | 11         |
# | Florianópolis         | SC     | Sul          | 9          |
# | Fortaleza             | CE     | Nordeste     | 9          |
# | Goiânia               | GO     | Centro-Oeste | 9          |
# | Guarulhos             | SP     | Sudeste      | 7          |
# | Joinville             | SC     | Sul          | 7          |
# | João Pessoa           | PB     | Nordeste     | 3          |
# | Maceió                | AL     | Nordeste     | 3          |
# | Manaus                | AM     | Norte        | 3          |
# | Natal                 | RN     | Nordeste     | 3          |
# | Niterói               | RJ     | Sudeste      | 9          |
# | Pelotas               | RS     | Sul          | 7          |
# | Porto Alegre          | RS     | Sul          | 11         |
# | Praia Grande          | SP     | Sudeste      | 7          |
# | Recife                | PE     | Nordeste     | 10         |
# | Ribeirão Preto        | SP     | Sudeste      | 7          |
# | Rio de Janeiro        | RJ     | Sudeste      | 17         |
# | Salvador              | BA     | Nordeste     | 11         |
# | Santo André           | SP     | Sudeste      | 7          |
# | Santos                | SP     | Sudeste      | 11         |
# | São Bernardo do Campo | SP     | Sudeste      | 11         |
# | São José (SC)         | SC     | Sul          | 7          |
# | São José do Rio Preto | SP     | Sudeste      | 7          |
# | São José dos Campos   | SP     | Sudeste      | 7          |
# | São Luís              | MA     | Nordeste     | 3          |
# | São Paulo             | SP     | Sudeste      | 17         |
# | Teresina              | PI     | Nordeste     | 3          |
# | Vitória               | ES     | Sudeste      | 3          |

# %% [markdown]
# ### Quantidade de dados por região:
# ![image.png](attachment:6241a999-a9b7-4739-9ac9-8432d891be11.png)

# %% [markdown]
# verificando geograficamente

# %%
dados = {
    "Cidade": ["Aracaju","Barueri","Belo Horizonte","Belém","Brasília","Campinas",
               "Campo Grande","Cuiabá","Curitiba","Florianópolis","Fortaleza",
               "Goiânia","Guarulhos","Joinville","João Pessoa","Maceió",
               "Manaus","Natal","Niterói","Pelotas","Porto Alegre",
               "Praia Grande","Recife","Ribeirão Preto","Rio de Janeiro",
               "Salvador","Santo André","Santos","São Bernardo do Campo",
               "São José (SC)","São José do Rio Preto","São José dos Campos",
               "São Luís","São Paulo","Teresina","Vitória"],

    "Latitude": [-10.9472,-23.5112,-19.9167,-1.4558,-15.7801,-22.9056,
                 -20.4428,-15.6014,-25.4284,-27.5954,-3.7172,
                 -16.6869,-23.4628,-26.3045,-7.115,-9.6658,
                 -3.119,-5.7945,-22.8858,-31.7654,-30.0346,
                 -24.0058,-8.0539,-21.1775,-22.9068,
                 -12.9714,-23.6666,-23.9608,-23.6944,
                 -27.6146,-20.8127,-23.2237,
                 -2.5307,-23.5505,-5.092,-20.3155],

    "Longitude": [-37.0731,-46.8765,-43.9345,-48.4902,-47.9292,-47.0608,
                  -54.6464,-56.0978,-49.2733,-48.548,-38.5433,
                  -49.2648,-46.5333,-48.8456,-34.8631,-35.735,
                  -60.0217,-35.211,-43.1153,-52.3376,-51.2177,
                  -46.4028,-34.8811,-47.8103,-43.1729,
                  -38.5014,-46.5322,-46.3339,-46.5654,
                  -48.634,-49.3765,-45.9009,
                  -44.3068,-46.6333,-42.8038,-40.3128],

    "Quantidade": [3,7,10,3,11,11,3,3,11,9,9,9,7,7,3,3,3,3,9,7,11,7,10,7,17,11,7,11,11,7,7,7,3,17,3,3]
}

df = pd.DataFrame(dados)

# Criar mapa de bolhas
fig = px.scatter_geo(
    df,
    lat="Latitude",
    lon="Longitude",
    size="Quantidade",

    labels="Cidade",
    projection="natural earth",
    scope="south america",
    width=1200,
    height=800
)

fig.update_layout(title="Quantidade de Amostras por Cidade")
fig.show()
